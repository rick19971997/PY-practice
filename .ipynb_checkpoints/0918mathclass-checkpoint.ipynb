# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [1, 1.2, 2.3, 4, 5]
y = [9, -8, 3, 4, 5]

# %%
plt.plot(x,y)

# %%
np.random.randint(1, 10, 10)
# Out:
# array([1, 1, 7, 9, 4, 4, 6, 8, 1, 6])

# %%
x = np.random.randn(100)
x.mean()
x.std()
# Out:
# 0.8485472342059064

# %%
plt.plot(x)

# %%
x = x + 37

# %%
x = x - 37

# %%
x = 5*x + 37
x.mean()
# Out:
# 37.487725995546995

# %%
x.std()
# Out:
# 4.242736171029529

# %%
x = np.linspace(0,10,200)

# %%
y = np.sin(x) + 0.8*x

# %%
plt.plot(x,y)

# %%
y = np.sin(x) + 0.8*x +0.4*np.random.randn(200)

# %%
plt.scatter(x,y)

# %%
## Markdown ##

# %%
# 加註解練習

# %% [markdown]
# # 最大標題
# ## 第二大標題
# ### 第三大
#
# 隨便搞操你媽
#
# 連續技: cntl+m, m

# %% [markdown]
# ### 分點說明
#
# * Python
# * Matplotlib
# * Numpy
# * pandas

# %% [markdown]
# ### 有順序的分項
#
# 1. PYthon
# 1. Matplotlib
# 1. Numpy

# %% [markdown]
# ### 做超連結
#
# [課程線上超連結]
# (http://bit.ly/iWantPython)

# %% [markdown]
# ### 支援 LaTex
#
# 我現在有一個函數 $f(x) = x^3 - 2x^2 + 5$
